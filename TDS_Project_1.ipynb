# %%
import requests
import time
import pandas as pd

# Optional: GitHub token to avoid rate limits-471
GITHUB_TOKEN = "xxx......xxx"       # add token
HEADERS = {"Authorization": f"token {GITHUB_TOKEN}"} if GITHUB_TOKEN else {}

# Clean and format company names
def clean_company_name(company):
    if not company:
        return None
    return company.strip().lstrip('@').upper()

# Fetch detailed user information
def fetch_user_details(username):
    url = f"https://api.github.com/users/{username}"
    response = requests.get(url, headers=HEADERS)
    if response.status_code != 200:
        print(f"Error fetching user details for {username}: {response.json()}")
        return None
    return response.json()

# Fetch users in Austin with 100+ followers, dynamically handle pagination
def fetch_users_in_Berlin():
    url = "https://api.github.com/search/users"
    query = "location:Berlin followers:>200"
    users = []
    page = 1

    while True:
        params = {"q": query, "per_page": 100, "page": page}
        response = requests.get(url, headers=HEADERS, params=params)

        if response.status_code != 200:
            print(f"Error: {response.json()}")
            break

        data = response.json().get("items", [])
        if not data:
            break  # No more data, exit the loop

        users.extend(data)
        print(f"Fetched {len(data)} users from page {page}.")
        page += 1  # Move to the next page
        time.sleep(2)  # Be polite to the API

    return users

# Fetch all repositories for a user, dynamically handle pagination
def fetch_repositories(username):
    url = f"https://api.github.com/users/{username}/repos"
    repos = []
    page = 1

    while True:
        params = {"per_page": 100, "page": page}
        response = requests.get(url, headers=HEADERS, params=params)

        if response.status_code != 200:
            print(f"Error fetching repos for {username}: {response.json()}")
            break

        data = response.json()
        if not data:
            break  # No more data, exit the loop

        repos.extend(data)
        print(f"Fetched {len(data)} repos from page {page} for {username}.")
        page += 1  # Move to the next page
        time.sleep(1)  # Be polite to the API

    return repos

# Main function to collect data and export to Excel
def main():
    users_data = []
    repos_data = []

    users = fetch_users_in_austin()
    print(f"Total users fetched: {len(users)}")

    for user in users:
        username = user["login"]
        user_details = fetch_user_details(username)

        if user_details:
            users_data.append({
                "login": user_details["login"],
                "name": user_details.get("name"),
                "company": clean_company_name(user_details.get("company")),
                "location": user_details.get("location"),
                "email": user_details.get("email"),
                "hireable": user_details.get("hireable"),
                "bio": user_details.get("bio"),
                "public_repos": user_details.get("public_repos"),
                "followers": user_details.get("followers"),
                "following": user_details.get("following"),
                "created_at": user_details.get("created_at"),
            })

        print(f"Fetching repositories for {username}...")
        repos = fetch_repositories(username)

        for repo in repos:
            repos_data.append({
                "login": username,
                "full_name": repo["full_name"],
                "created_at": repo["created_at"],
                "stargazers_count": repo["stargazers_count"],
                "watchers_count": repo["watchers_count"],
                "language": repo["language"],
                "has_projects": repo["has_projects"],
                "has_wiki": repo["has_wiki"],
                "license_name": repo["license"]["name"] if repo.get("license") else None
            })

    # Convert data to DataFrames and save to Excel
    users_df = pd.DataFrame(users_data)
    repos_df = pd.DataFrame(repos_data)

    users_df.to_excel("usersall.xlsx", index=False)
    repos_df.to_excel("repositoriesall.xlsx", index=False)

    print("Data saved to users.xlsx and repositories.xlsx")

if __name__ == "__main__":
    main()
# Out:
# Fetched 100 users from page 1.
# Fetched 100 users from page 2.
# Fetched 100 users from page 3.
# Fetched 100 users from page 4.
# Fetched 100 users from page 5.
# Fetched 98 users from page 6.
# Total users fetched: 598
# Fetching repositories for tiangolo...
# Fetched 71 repos from page 1 for tiangolo.
# Fetching repositories for schacon...
# Fetched 100 repos from page 1 for schacon.
# Fetched 100 repos from page 2 for schacon.
# Fetched 15 repos from page 3 for schacon.
# Fetching repositories for rwieruch...
# Fetched 100 repos from page 1 for rwieruch.
# Fetched 51 repos from page 2 for rwieruch.
# Fetching repositories for shuding...
# Fetched 100 repos from page 1 for shuding.
# Fetched 49 repos from page 2 for shuding.
# Fetching repositories for android10...
# Fetched 79 repos from page 1 for android10.
# Fetching repositories for marijnh...
# Fetched 54 repos from page 1 for marijnh.
# Fetching repositories for mxmnk...
# Fetched 7 repos from page 1 for mxmnk.
# Fetching repositories for nikic...
# Fetched 100 repos from page 1 for nikic.
# Fetched 10 repos from page 2 for nikic.
# Fetching repositories for greenrobot...
# Fetched 22 repos from page 1 for greenrobot.
# Fetching repositories for sebastianruder...
# Fetched 32 repos from page 1 for sebastianruder.
# Fetching repositories for vakila...
# Fetched 48 repos from page 1 for vakila.
# Fetching repositories for tonsky...
# Fetched 100 repos from page 1 for tonsky.
# Fetched 15 repos from page 2 for tonsky.
# Fetching repositories for felixge...
# Fetched 100 repos from page 1 for felixge.
# Fetched 100 repos from page 2 for felixge.
# Fetched 85 repos from page 3 for felixge.
# Fetching repositories for alexeygrigorev...
# Fetched 100 repos from page 1 for alexeygrigorev.
# Fetched 29 repos from page 2 for alexeygrigorev.
# Fetching repositories for hanxiao...
# Fetched 100 repos from page 1 for hanxiao.
# Fetched 6 repos from page 2 for hanxiao.
# Fetching repositories for ines...
# Fetched 19 repos from page 1 for ines.
# Fetching repositories for apaszke...
# Fetched 73 repos from page 1 for apaszke.
# Fetching repositories for lewagon...
# Fetched 100 repos from page 1 for lewagon.
# Fetched 75 repos from page 2 for lewagon.
# Fetching repositories for codebytere...
# Fetched 100 repos from page 1 for codebytere.
# Fetched 4 repos from page 2 for codebytere.
# Fetching repositories for prisma...
# Fetched 100 repos from page 1 for prisma.
# Fetched 52 repos from page 2 for prisma.
# Fetching repositories for armancodv...
# Fetched 51 repos from page 1 for armancodv.
# Fetching repositories for peterbourgon...
# Fetched 56 repos from page 1 for peterbourgon.
# Fetching repositories for vanhauser-thc...
# Fetched 44 repos from page 1 for vanhauser-thc.
# Fetching repositories for KittyGiraudel...
# Fetched 51 repos from page 1 for KittyGiraudel.
# Fetching repositories for dashersw...
# Fetched 100 repos from page 1 for dashersw.
# Fetched 99 repos from page 2 for dashersw.
# Fetching repositories for codepo8...
# Fetched 100 repos from page 1 for codepo8.
# Fetched 100 repos from page 2 for codepo8.
# Fetched 100 repos from page 3 for codepo8.
# Fetched 19 repos from page 4 for codepo8.
# Fetching repositories for nlohmann...
# Fetched 42 repos from page 1 for nlohmann.
# Fetching repositories for floooh...
# Fetched 100 repos from page 1 for floooh.
# Fetched 48 repos from page 2 for floooh.
# Fetching repositories for cure53...
# Fetched 20 repos from page 1 for cure53.
# Fetching repositories for nisrulz...
# Fetched 72 repos from page 1 for nisrulz.
# Fetching repositories for vietnh1009...
# Fetched 39 repos from page 1 for vietnh1009.
# Fetching repositories for pepelsbey...
# Fetched 46 repos from page 1 for pepelsbey.
# Fetching repositories for nschloe...
# Fetched 94 repos from page 1 for nschloe.
# Fetching repositories for spacejam...
# Fetched 100 repos from page 1 for spacejam.
# Fetched 90 repos from page 2 for spacejam.
# Fetching repositories for ligi...
# Fetched 100 repos from page 1 for ligi.
# Fetched 100 repos from page 2 for ligi.
# Fetched 100 repos from page 3 for ligi.
# Fetched 63 repos from page 4 for ligi.
# Fetching repositories for justadudewhohacks...
# Fetched 41 repos from page 1 for justadudewhohacks.
# Fetching repositories for anaisbetts...
# Fetched 100 repos from page 1 for anaisbetts.
# Fetched 100 repos from page 2 for anaisbetts.
# Fetched 100 repos from page 3 for anaisbetts.
# Fetched 25 repos from page 4 for anaisbetts.
# Fetching repositories for typst...
# Fetched 25 repos from page 1 for typst.
# Fetching repositories for robb...
# Fetched 57 repos from page 1 for robb.
# Fetching repositories for schickling...
# Fetched 72 repos from page 1 for schickling.
# Fetching repositories for rkh...
# Fetched 100 repos from page 1 for rkh.
# Fetched 100 repos from page 2 for rkh.
# Fetched 1 repos from page 3 for rkh.
# Fetching repositories for withoutboats...
# Fetched 71 repos from page 1 for withoutboats.
# Fetching repositories for honnibal...
# Fetched 58 repos from page 1 for honnibal.
# Fetching repositories for janl...
# Fetched 100 repos from page 1 for janl.
# Fetched 100 repos from page 2 for janl.
# Fetched 3 repos from page 3 for janl.
# Fetching repositories for Roaa94...
# Fetched 30 repos from page 1 for Roaa94.
# Fetching repositories for frozeman...
# Fetched 100 repos from page 1 for frozeman.
# Fetched 17 repos from page 2 for frozeman.
# Fetching repositories for z3tt...
# Fetched 48 repos from page 1 for z3tt.
# Fetching repositories for vas3k...
# Fetched 27 repos from page 1 for vas3k.
# Fetching repositories for mttkay...
# Fetched 50 repos from page 1 for mttkay.
# Fetching repositories for leo...
# Fetched 57 repos from page 1 for leo.
# Fetching repositories for tomaka...
# Fetched 100 repos from page 1 for tomaka.
# Fetched 100 repos from page 2 for tomaka.
# Fetched 45 repos from page 3 for tomaka.
# Fetching repositories for johnkil...
# Fetched 40 repos from page 1 for johnkil.
# Fetching repositories for mxschmitt...
# Fetched 100 repos from page 1 for mxschmitt.
# Fetched 100 repos from page 2 for mxschmitt.
# Fetched 7 repos from page 3 for mxschmitt.
# Fetching repositories for smakosh...
# Fetched 100 repos from page 1 for smakosh.
# Fetched 32 repos from page 2 for smakosh.
# Fetching repositories for poettering...
# Fetched 17 repos from page 1 for poettering.
# Fetching repositories for hynek...
# Fetched 32 repos from page 1 for hynek.
# Fetching repositories for TejasQ...
# Fetched 100 repos from page 1 for TejasQ.
# Fetched 36 repos from page 2 for TejasQ.
# Fetching repositories for AmruthPillai...
# Fetched 100 repos from page 1 for AmruthPillai.
# Fetched 78 repos from page 2 for AmruthPillai.
# Fetching repositories for chriseth...
# Fetched 87 repos from page 1 for chriseth.
# Fetching repositories for roji...
# Fetched 81 repos from page 1 for roji.
# Fetching repositories for justinmk...
# Fetched 34 repos from page 1 for justinmk.
# Fetching repositories for brianamarie...
# Fetched 100 repos from page 1 for brianamarie.
# Fetched 39 repos from page 2 for brianamarie.
# Fetching repositories for datitran...
# Fetched 61 repos from page 1 for datitran.
# Fetching repositories for arash-hacker...
# Fetched 76 repos from page 1 for arash-hacker.
# Fetching repositories for alireza0...
# Fetched 11 repos from page 1 for alireza0.
# Fetching repositories for maciejwalkowiak...
# Fetched 100 repos from page 1 for maciejwalkowiak.
# Fetched 46 repos from page 2 for maciejwalkowiak.
# Fetching repositories for eps1lon...
# Fetched 100 repos from page 1 for eps1lon.
# Fetched 100 repos from page 2 for eps1lon.
# Fetched 100 repos from page 3 for eps1lon.
# Fetched 36 repos from page 4 for eps1lon.
# Fetching repositories for MohamedMesto...
# Fetched 100 repos from page 1 for MohamedMesto.
# Fetched 3 repos from page 2 for MohamedMesto.
# Fetching repositories for solegalli...
# Fetched 21 repos from page 1 for solegalli.
# Fetching repositories for mugli...
# Fetched 37 repos from page 1 for mugli.
# Fetching repositories for pedromassango...
# Fetched 100 repos from page 1 for pedromassango.
# Fetched 100 repos from page 2 for pedromassango.
# Fetched 7 repos from page 3 for pedromassango.
# Fetching repositories for Byron...
# Fetched 100 repos from page 1 for Byron.
# Fetched 98 repos from page 2 for Byron.
# Fetching repositories for aFarkas...
# Fetched 65 repos from page 1 for aFarkas.
# Fetching repositories for mr-mig...
# Fetched 47 repos from page 1 for mr-mig.
# Fetching repositories for gka...
# Fetched 38 repos from page 1 for gka.
# Fetching repositories for cytopia...
# Fetched 100 repos from page 1 for cytopia.
# Fetched 14 repos from page 2 for cytopia.
# Fetching repositories for explosion...
# Fetched 76 repos from page 1 for explosion.
# Fetching repositories for omz...
# Fetched 13 repos from page 1 for omz.
# Fetching repositories for sujinleeme...
# Fetched 54 repos from page 1 for sujinleeme.
# Fetching repositories for tgalal...
# Fetched 40 repos from page 1 for tgalal.
# Fetching repositories for stefanjudis...
# Fetched 100 repos from page 1 for stefanjudis.
# Fetched 100 repos from page 2 for stefanjudis.
# Fetching repositories for cs-MohamedAyman...
# Fetched 13 repos from page 1 for cs-MohamedAyman.
# Fetching repositories for dmonad...
# Fetched 42 repos from page 1 for dmonad.
# Fetching repositories for ojack...
# Fetched 100 repos from page 1 for ojack.
# Fetched 13 repos from page 2 for ojack.
# Fetching repositories for beorn7...
# Fetched 33 repos from page 1 for beorn7.
# Fetching repositories for camunda...
# Fetched 100 repos from page 1 for camunda.
# Fetched 53 repos from page 2 for camunda.
# Fetching repositories for olilarkin...
# Fetched 100 repos from page 1 for olilarkin.
# Fetched 8 repos from page 2 for olilarkin.
# Fetching repositories for deliveryhero...
# Fetched 86 repos from page 1 for deliveryhero.
# Fetching repositories for berndruecker...
# Fetched 81 repos from page 1 for berndruecker.
# Fetching repositories for xct...
# Fetched 37 repos from page 1 for xct.
# Fetching repositories for rxrbln...
# Fetched 19 repos from page 1 for rxrbln.
# Fetching repositories for davidchambers...
# Fetched 100 repos from page 1 for davidchambers.
# Fetched 6 repos from page 2 for davidchambers.
# Fetching repositories for adamwiggins...
# Fetched 99 repos from page 1 for adamwiggins.
# Fetching repositories for naderman...
# Fetched 91 repos from page 1 for naderman.
# Fetching repositories for fjl...
# Fetched 100 repos from page 1 for fjl.
# Fetched 12 repos from page 2 for fjl.
# Fetching repositories for vitormalencar...
# Fetched 47 repos from page 1 for vitormalencar.
# Fetching repositories for moklick...
# Fetched 100 repos from page 1 for moklick.
# Fetched 39 repos from page 2 for moklick.
# Fetching repositories for rpolonsky...
# Fetched 5 repos from page 1 for rpolonsky.
# Fetching repositories for kashif...
# Fetched 100 repos from page 1 for kashif.
# Fetched 100 repos from page 2 for kashif.
# Fetched 20 repos from page 3 for kashif.
# Fetching repositories for LilithWittmann...
# Fetched 46 repos from page 1 for LilithWittmann.
# Fetching repositories for jamesmunns...
# Fetched 100 repos from page 1 for jamesmunns.
# Fetched 100 repos from page 2 for jamesmunns.
# Fetched 100 repos from page 3 for jamesmunns.
# Fetched 14 repos from page 4 for jamesmunns.
# Fetching repositories for pudo...
# Fetched 49 repos from page 1 for pudo.
# Fetching repositories for javierbyte...
# Fetched 53 repos from page 1 for javierbyte.
# Fetching repositories for meh...
# Fetched 100 repos from page 1 for meh.
# Fetched 100 repos from page 2 for meh.
# Fetched 100 repos from page 3 for meh.
# Fetched 70 repos from page 4 for meh.
# Fetching repositories for rednafi...
# Fetched 68 repos from page 1 for rednafi.
# Fetching repositories for visenger...
# Fetched 79 repos from page 1 for visenger.
# Fetching repositories for brancz...
# Fetched 100 repos from page 1 for brancz.
# Fetched 63 repos from page 2 for brancz.
# Fetching repositories for zaraco...
# Fetched 30 repos from page 1 for zaraco.
# Fetching repositories for spacekookie...
# Fetched 100 repos from page 1 for spacekookie.
# Fetched 63 repos from page 2 for spacekookie.
# Fetching repositories for ptaoussanis...
# Fetched 52 repos from page 1 for ptaoussanis.
# Fetching repositories for traviscibot...
# Fetching repositories for deepset-ai...
# Fetched 61 repos from page 1 for deepset-ai.
# Fetching repositories for mlent...
# Fetched 42 repos from page 1 for mlent.
# Fetching repositories for emad-elsaid...
# Fetched 91 repos from page 1 for emad-elsaid.
# Fetching repositories for paolorotolo...
# Fetched 91 repos from page 1 for paolorotolo.
# Fetching repositories for panique...
# Fetched 26 repos from page 1 for panique.
# Fetching repositories for falkTX...
# Fetched 100 repos from page 1 for falkTX.
# Fetched 19 repos from page 2 for falkTX.
# Fetching repositories for kof...
# Fetched 100 repos from page 1 for kof.
# Fetched 13 repos from page 2 for kof.
# Fetching repositories for pepicrft...
# Fetched 37 repos from page 1 for pepicrft.
# Fetching repositories for hramezani...
# Fetched 92 repos from page 1 for hramezani.
# Fetching repositories for cebe...
# Fetched 100 repos from page 1 for cebe.
# Fetched 100 repos from page 2 for cebe.
# Fetched 58 repos from page 3 for cebe.
# Fetching repositories for PurpleBooth...
# Fetched 100 repos from page 1 for PurpleBooth.
# Fetched 86 repos from page 2 for PurpleBooth.
# Fetching repositories for bergie...
# Fetched 100 repos from page 1 for bergie.
# Fetched 29 repos from page 2 for bergie.
# Fetching repositories for rahmonov...
# Fetched 40 repos from page 1 for rahmonov.
# Fetching repositories for bkchr...
# Fetched 100 repos from page 1 for bkchr.
# Fetched 31 repos from page 2 for bkchr.
# Fetching repositories for derhuerst...
# Fetched 100 repos from page 1 for derhuerst.
# Fetched 100 repos from page 2 for derhuerst.
# Fetched 100 repos from page 3 for derhuerst.
# Fetched 100 repos from page 4 for derhuerst.
# Fetched 100 repos from page 5 for derhuerst.
# Fetched 82 repos from page 6 for derhuerst.
# Fetching repositories for nikolasburk...
# Fetched 100 repos from page 1 for nikolasburk.
# Fetched 100 repos from page 2 for nikolasburk.
# Fetched 2 repos from page 3 for nikolasburk.
# Fetching repositories for svenfuchs...
# Fetched 100 repos from page 1 for svenfuchs.
# Fetched 45 repos from page 2 for svenfuchs.
# Fetching repositories for areyou1or0...
# Fetched 6 repos from page 1 for areyou1or0.
# Fetching repositories for tasomaniac...
# Fetched 100 repos from page 1 for tasomaniac.
# Fetched 11 repos from page 2 for tasomaniac.
# Fetching repositories for Phantas0s...
# Fetched 97 repos from page 1 for Phantas0s.
# Fetching repositories for ndrplz...
# Fetched 23 repos from page 1 for ndrplz.
# Fetching repositories for voronianski...
# Fetched 100 repos from page 1 for voronianski.
# Fetched 89 repos from page 2 for voronianski.
# Fetching repositories for zalando...
# Fetched 49 repos from page 1 for zalando.
# Fetching repositories for maateen...
# Fetched 38 repos from page 1 for maateen.
# Fetching repositories for lilic...
# Fetched 92 repos from page 1 for lilic.
# Fetching repositories for Expensify...
# Fetched 57 repos from page 1 for Expensify.
# Fetching repositories for fzerorubigd...
# Fetched 100 repos from page 1 for fzerorubigd.
# Fetched 53 repos from page 2 for fzerorubigd.
# Fetching repositories for endocrimes...
# Fetched 100 repos from page 1 for endocrimes.
# Fetched 100 repos from page 2 for endocrimes.
# Fetched 89 repos from page 3 for endocrimes.
# Fetching repositories for kjam...
# Fetched 41 repos from page 1 for kjam.
# Fetching repositories for plutov...
# Fetched 69 repos from page 1 for plutov.
# Fetching repositories for neelance...
# Fetched 61 repos from page 1 for neelance.
# Fetching repositories for codergogoi...
# Fetched 63 repos from page 1 for codergogoi.
# Fetching repositories for skade...
# Fetched 100 repos from page 1 for skade.
# Fetched 100 repos from page 2 for skade.
# Fetched 100 repos from page 3 for skade.
# Fetched 100 repos from page 4 for skade.
# Fetched 20 repos from page 5 for skade.
# Fetching repositories for anapaulagomes...
# Fetched 62 repos from page 1 for anapaulagomes.
# Fetching repositories for infusion...
# Fetched 35 repos from page 1 for infusion.
# Fetching repositories for RobertTLange...
# Fetched 36 repos from page 1 for RobertTLange.
# Fetching repositories for burakcan...
# Fetched 62 repos from page 1 for burakcan.
# Fetching repositories for msaaddev...
# Fetched 100 repos from page 1 for msaaddev.
# Fetched 100 repos from page 2 for msaaddev.
# Fetched 11 repos from page 3 for msaaddev.
# Fetching repositories for sschmid...
# Fetched 61 repos from page 1 for sschmid.
# Fetching repositories for SpaceK33z...
# Fetched 87 repos from page 1 for SpaceK33z.
# Fetching repositories for generall...
# Fetched 100 repos from page 1 for generall.
# Fetching repositories for debris...
# Fetched 99 repos from page 1 for debris.
# Fetching repositories for rootzoll...
# Fetched 41 repos from page 1 for rootzoll.
# Fetching repositories for m0nad...
# Fetched 23 repos from page 1 for m0nad.
# Fetching repositories for janpio...
# Fetched 100 repos from page 1 for janpio.
# Fetched 100 repos from page 2 for janpio.
# Fetched 100 repos from page 3 for janpio.
# Fetched 100 repos from page 4 for janpio.
# Fetched 71 repos from page 5 for janpio.
# Fetching repositories for cjwirth...
# Fetched 37 repos from page 1 for cjwirth.
# Fetching repositories for ozgurozturknet...
# Fetched 32 repos from page 1 for ozgurozturknet.
# Fetching repositories for XAMPPRocky...
# Fetched 100 repos from page 1 for XAMPPRocky.
# Fetched 37 repos from page 2 for XAMPPRocky.
# Fetching repositories for increpare...
# Fetched 100 repos from page 1 for increpare.
# Fetched 51 repos from page 2 for increpare.
# Fetching repositories for philippjfr...
# Fetched 95 repos from page 1 for philippjfr.
# Fetching repositories for dereuromark...
# Fetched 91 repos from page 1 for dereuromark.
# Fetching repositories for iuridepaula...
# Fetched 2 repos from page 1 for iuridepaula.
# Fetching repositories for LefterisJP...
# Fetched 100 repos from page 1 for LefterisJP.
# Fetched 51 repos from page 2 for LefterisJP.
# Fetching repositories for Conchylicultor...
# Fetched 43 repos from page 1 for Conchylicultor.
# Fetching repositories for Tienisto...
# Fetched 45 repos from page 1 for Tienisto.
# Fetching repositories for localheinz...
# Fetched 100 repos from page 1 for localheinz.
# Fetched 100 repos from page 2 for localheinz.
# Fetched 100 repos from page 3 for localheinz.
# Fetched 100 repos from page 4 for localheinz.
# Fetched 52 repos from page 5 for localheinz.
# Fetching repositories for matthiasn...
# Fetched 100 repos from page 1 for matthiasn.
# Fetched 22 repos from page 2 for matthiasn.
# Fetching repositories for q9f...
# Fetched 74 repos from page 1 for q9f.
# Fetching repositories for chrieke...
# Fetched 38 repos from page 1 for chrieke.
# Fetching repositories for tcurdt...
# Fetched 60 repos from page 1 for tcurdt.
# Fetching repositories for NikolaiT...
# Fetched 51 repos from page 1 for NikolaiT.
# Fetching repositories for thatisuday...
# Fetched 60 repos from page 1 for thatisuday.
# Fetching repositories for rumyantseva...
# Fetched 78 repos from page 1 for rumyantseva.
# Fetching repositories for salihgueler...
# Fetched 62 repos from page 1 for salihgueler.
# Fetching repositories for iotaledger...
# Fetched 100 repos from page 1 for iotaledger.
# Fetched 100 repos from page 2 for iotaledger.
# Fetched 45 repos from page 3 for iotaledger.
# Fetching repositories for mtdvio...
# Fetched 5 repos from page 1 for mtdvio.
# Fetching repositories for splitbrain...
# Fetched 100 repos from page 1 for splitbrain.
# Fetched 66 repos from page 2 for splitbrain.
# Fetching repositories for juliusv...
# Fetched 80 repos from page 1 for juliusv.
# Fetching repositories for hukl...
# Fetched 94 repos from page 1 for hukl.
# Fetching repositories for wolfv...
# Fetched 100 repos from page 1 for wolfv.
# Fetched 100 repos from page 2 for wolfv.
# Fetched 100 repos from page 3 for wolfv.
# Fetched 100 repos from page 4 for wolfv.
# Fetched 92 repos from page 5 for wolfv.
# Fetching repositories for kakkoyun...
# Fetched 100 repos from page 1 for kakkoyun.
# Fetched 69 repos from page 2 for kakkoyun.
# Fetching repositories for Jolg42...
# Fetched 100 repos from page 1 for Jolg42.
# Fetched 57 repos from page 2 for Jolg42.
# Fetching repositories for domschiener...
# Fetched 33 repos from page 1 for domschiener.
# Fetching repositories for manashmandal...
# Fetched 100 repos from page 1 for manashmandal.
# Fetched 100 repos from page 2 for manashmandal.
# Fetched 7 repos from page 3 for manashmandal.
# Fetching repositories for ebrugulec...
# Fetched 32 repos from page 1 for ebrugulec.
# Fetching repositories for kaisermann...
# Fetched 84 repos from page 1 for kaisermann.
# Fetching repositories for seyfer...
# Fetched 100 repos from page 1 for seyfer.
# Fetched 9 repos from page 2 for seyfer.
# Fetching repositories for rohan20...
# Fetched 100 repos from page 1 for rohan20.
# Fetched 24 repos from page 2 for rohan20.
# Fetching repositories for wix...
# Fetched 19 repos from page 1 for wix.
# Fetching repositories for cketti...
# Fetched 100 repos from page 1 for cketti.
# Fetched 5 repos from page 2 for cketti.
# Fetching repositories for tasdikrahman...
# Fetched 100 repos from page 1 for tasdikrahman.
# Fetched 30 repos from page 2 for tasdikrahman.
# Fetching repositories for greyblake...
# Fetched 100 repos from page 1 for greyblake.
# Fetched 16 repos from page 2 for greyblake.
# Fetching repositories for berstend...
# Fetched 84 repos from page 1 for berstend.
# Fetching repositories for ThisIsMissEm...
# Fetched 100 repos from page 1 for ThisIsMissEm.
# Fetched 77 repos from page 2 for ThisIsMissEm.
# Fetching repositories for christianparpart...
# Fetched 100 repos from page 1 for christianparpart.
# Fetched 21 repos from page 2 for christianparpart.
# Fetching repositories for kostasx...
# Fetched 100 repos from page 1 for kostasx.
# Fetched 100 repos from page 2 for kostasx.
# Fetched 100 repos from page 3 for kostasx.
# Fetched 47 repos from page 4 for kostasx.
# Fetching repositories for davidsbatista...
# Fetched 39 repos from page 1 for davidsbatista.
# Fetching repositories for johannesjo...
# Fetched 56 repos from page 1 for johannesjo.
# Fetching repositories for ahmedash95...
# Fetched 100 repos from page 1 for ahmedash95.
# Fetched 100 repos from page 2 for ahmedash95.
# Fetched 93 repos from page 3 for ahmedash95.
# Fetching repositories for lislis...
# Fetched 100 repos from page 1 for lislis.
# Fetched 94 repos from page 2 for lislis.
# Fetching repositories for sheremet-va...
# Fetched 48 repos from page 1 for sheremet-va.
# Fetching repositories for AnirudhDagar...
# Fetched 69 repos from page 1 for AnirudhDagar.
# Fetching repositories for arximboldi...
# Fetched 73 repos from page 1 for arximboldi.
# Fetching repositories for mhagger...
# Fetched 16 repos from page 1 for mhagger.
# Fetching repositories for boopathi...
# Fetched 100 repos from page 1 for boopathi.
# Fetched 74 repos from page 2 for boopathi.
# Fetching repositories for DonnchaC...
# Fetched 77 repos from page 1 for DonnchaC.
# Fetching repositories for gouthamve...
# Fetched 100 repos from page 1 for gouthamve.
# Fetched 81 repos from page 2 for gouthamve.
# Fetching repositories for jackrusher...
# Fetched 21 repos from page 1 for jackrusher.
# Fetching repositories for matthiasplappert...
# Fetched 51 repos from page 1 for matthiasplappert.
# Fetching repositories for nuhkoca...
# Fetched 100 repos from page 1 for nuhkoca.
# Fetched 31 repos from page 2 for nuhkoca.
# Fetching repositories for faressoft...
# Fetched 78 repos from page 1 for faressoft.
# Fetching repositories for xeolabs...
# Fetched 100 repos from page 1 for xeolabs.
# Fetched 72 repos from page 2 for xeolabs.
# Fetching repositories for AriaMinaei...
# Fetched 79 repos from page 1 for AriaMinaei.
# Fetching repositories for xyflow...
# Fetched 20 repos from page 1 for xyflow.
# Fetching repositories for lukasmasuch...
# Fetched 62 repos from page 1 for lukasmasuch.
# Fetching repositories for hellofresh...
# Fetched 100 repos from page 1 for hellofresh.
# Fetched 32 repos from page 2 for hellofresh.
# Fetching repositories for ikrum...
# Fetched 32 repos from page 1 for ikrum.
# Fetching repositories for simoneas02...
# Fetched 50 repos from page 1 for simoneas02.
# Fetching repositories for asus4...
# Fetched 100 repos from page 1 for asus4.
# Fetched 51 repos from page 2 for asus4.
# Fetching repositories for x42...
# Fetched 100 repos from page 1 for x42.
# Fetched 25 repos from page 2 for x42.
# Fetching repositories for blueyed...
# Fetched 100 repos from page 1 for blueyed.
# Fetched 100 repos from page 2 for blueyed.
# Fetched 100 repos from page 3 for blueyed.
# Fetched 100 repos from page 4 for blueyed.
# Fetched 100 repos from page 5 for blueyed.
# Fetched 95 repos from page 6 for blueyed.
# Fetching repositories for marinalimeira...
# Fetched 84 repos from page 1 for marinalimeira.
# Fetching repositories for peterp...
# Fetched 30 repos from page 1 for peterp.
# Fetching repositories for metalmatze...
# Fetched 100 repos from page 1 for metalmatze.
# Fetched 2 repos from page 2 for metalmatze.
# Fetching repositories for segunfamisa...
# Fetched 65 repos from page 1 for segunfamisa.
# Fetching repositories for stefanw...
# Fetched 100 repos from page 1 for stefanw.
# Fetched 61 repos from page 2 for stefanw.
# Fetching repositories for ethanfrey...
# Fetched 62 repos from page 1 for ethanfrey.
# Fetching repositories for PragTob...
# Fetched 100 repos from page 1 for PragTob.
# Fetched 100 repos from page 2 for PragTob.
# Fetched 16 repos from page 3 for PragTob.
# Fetching repositories for roidrage...
# Fetched 100 repos from page 1 for roidrage.
# Fetched 35 repos from page 2 for roidrage.
# Fetching repositories for hwclass...
# Fetched 100 repos from page 1 for hwclass.
# Fetched 66 repos from page 2 for hwclass.
# Fetching repositories for juanitorduz...
# Fetched 33 repos from page 1 for juanitorduz.
# Fetching repositories for okwme...
# Fetched 100 repos from page 1 for okwme.
# Fetched 48 repos from page 2 for okwme.
# Fetching repositories for rdilruba...
# Fetched 32 repos from page 1 for rdilruba.
# Fetching repositories for ivangfr...
# Fetched 61 repos from page 1 for ivangfr.
# Fetching repositories for abhishek-ch...
# Fetched 66 repos from page 1 for abhishek-ch.
# Fetching repositories for durran...
# Fetched 54 repos from page 1 for durran.
# Fetching repositories for chrisgrieser...
# Fetched 79 repos from page 1 for chrisgrieser.
# Fetching repositories for vertexclique...
# Fetched 100 repos from page 1 for vertexclique.
# Fetched 35 repos from page 2 for vertexclique.
# Fetching repositories for aabouzaid...
# Fetched 96 repos from page 1 for aabouzaid.
# Fetching repositories for sagar-viradiya...
# Fetched 75 repos from page 1 for sagar-viradiya.
# Fetching repositories for ahmedeltaher...
# Fetched 51 repos from page 1 for ahmedeltaher.
# Fetching repositories for DominicBreuker...
# Fetched 84 repos from page 1 for DominicBreuker.
# Fetching repositories for mxmxmx...
# Fetched 16 repos from page 1 for mxmxmx.
# Fetching repositories for photoprism...
# Fetched 16 repos from page 1 for photoprism.
# Fetching repositories for diessica...
# Fetched 43 repos from page 1 for diessica.
# Fetching repositories for christophergandrud...
# Fetched 100 repos from page 1 for christophergandrud.
# Fetched 47 repos from page 2 for christophergandrud.
# Fetching repositories for drogus...
# Fetched 100 repos from page 1 for drogus.
# Fetched 76 repos from page 2 for drogus.
# Fetching repositories for tessr...
# Fetched 25 repos from page 1 for tessr.
# Fetching repositories for SimonDanisch...
# Fetched 100 repos from page 1 for SimonDanisch.
# Fetched 100 repos from page 2 for SimonDanisch.
# Fetched 29 repos from page 3 for SimonDanisch.
# Fetching repositories for KutayAkalin...
# Fetched 28 repos from page 1 for KutayAkalin.
# Fetching repositories for Ohara124c41...
# Fetched 100 repos from page 1 for Ohara124c41.
# Fetched 42 repos from page 2 for Ohara124c41.
# Fetching repositories for IRCSS...
# Fetched 31 repos from page 1 for IRCSS.
# Fetching repositories for mntmn...
# Fetched 61 repos from page 1 for mntmn.
# Fetching repositories for ff6347...
# Fetched 100 repos from page 1 for ff6347.
# Fetched 100 repos from page 2 for ff6347.
# Fetched 100 repos from page 3 for ff6347.
# Fetched 100 repos from page 4 for ff6347.
# Fetched 100 repos from page 5 for ff6347.
# Fetched 18 repos from page 6 for ff6347.
# Fetching repositories for berinhard...
# Fetched 70 repos from page 1 for berinhard.
# Fetching repositories for kianenigma...
# Fetched 81 repos from page 1 for kianenigma.
# Fetching repositories for SuperQ...
# Fetched 100 repos from page 1 for SuperQ.
# Fetched 70 repos from page 2 for SuperQ.
# Fetching repositories for gwens...
# Fetching repositories for hellosagar...
# Fetched 96 repos from page 1 for hellosagar.
# Fetching repositories for tmbo...
# Fetched 62 repos from page 1 for tmbo.
# Fetching repositories for delucis...
# Fetched 98 repos from page 1 for delucis.
# Fetching repositories for hanshuebner...
# Fetched 100 repos from page 1 for hanshuebner.
# Fetched 100 repos from page 2 for hanshuebner.
# Fetched 2 repos from page 3 for hanshuebner.
# Fetching repositories for ueberdosis...
# Fetched 34 repos from page 1 for ueberdosis.
# Fetching repositories for hackebrot...
# Fetched 100 repos from page 1 for hackebrot.
# Fetched 23 repos from page 2 for hackebrot.
# Fetching repositories for almaleksia...
# Fetched 14 repos from page 1 for almaleksia.
# Fetching repositories for AlexDenisov...
# Fetched 81 repos from page 1 for AlexDenisov.
# Fetching repositories for danascript...
# Fetched 44 repos from page 1 for danascript.
# Fetching repositories for tarek360...
# Fetched 87 repos from page 1 for tarek360.
# Fetching repositories for sschuberth...
# Fetched 100 repos from page 1 for sschuberth.
# Fetched 18 repos from page 2 for sschuberth.
# Fetching repositories for tillrohrmann...
# Fetched 100 repos from page 1 for tillrohrmann.
# Fetched 5 repos from page 2 for tillrohrmann.
# Fetching repositories for esc...
# Fetched 46 repos from page 1 for esc.
# Fetching repositories for mrackwitz...
# Fetched 100 repos from page 1 for mrackwitz.
# Fetched 2 repos from page 2 for mrackwitz.
# Fetching repositories for hagenburger...
# Fetched 64 repos from page 1 for hagenburger.
# Fetching repositories for w0rm...
# Fetched 48 repos from page 1 for w0rm.
# Fetching repositories for cpanato...
# Fetched 100 repos from page 1 for cpanato.
# Fetched 100 repos from page 2 for cpanato.
# Fetched 100 repos from page 3 for cpanato.
# Fetched 53 repos from page 4 for cpanato.
# Fetching repositories for azproduction...
# Fetched 96 repos from page 1 for azproduction.
# Fetching repositories for ForsakenHarmony...
# Fetched 100 repos from page 1 for ForsakenHarmony.
# Fetched 39 repos from page 2 for ForsakenHarmony.
# Fetching repositories for lucasmichot...
# Fetched 20 repos from page 1 for lucasmichot.
# Fetching repositories for gusgad...
# Fetched 29 repos from page 1 for gusgad.
# Fetching repositories for lastzero...
# Fetched 48 repos from page 1 for lastzero.
# Fetching repositories for jrieke...
# Fetched 100 repos from page 1 for jrieke.
# Fetched 1 repos from page 2 for jrieke.
# Fetching repositories for ndom91...
# Fetched 100 repos from page 1 for ndom91.
# Fetched 30 repos from page 2 for ndom91.
# Fetching repositories for krother...
# Fetched 81 repos from page 1 for krother.
# Fetching repositories for adbar...
# Fetched 26 repos from page 1 for adbar.
# Fetching repositories for turian...
# Fetched 100 repos from page 1 for turian.
# Fetched 54 repos from page 2 for turian.
# Fetching repositories for slint-ui...
# Fetched 36 repos from page 1 for slint-ui.
# Fetching repositories for afuh...
# Fetched 52 repos from page 1 for afuh.
# Fetching repositories for jpkrohling...
# Fetched 100 repos from page 1 for jpkrohling.
# Fetched 100 repos from page 2 for jpkrohling.
# Fetched 100 repos from page 3 for jpkrohling.
# Fetched 93 repos from page 4 for jpkrohling.
# Fetching repositories for opf...
# Fetched 88 repos from page 1 for opf.
# Fetching repositories for andywer...
# Fetched 100 repos from page 1 for andywer.
# Fetched 2 repos from page 2 for andywer.
# Fetching repositories for fritzing...
# Fetched 17 repos from page 1 for fritzing.
# Fetching repositories for timpritlove...
# Fetched 14 repos from page 1 for timpritlove.
# Fetching repositories for aksakalli...
# Fetched 49 repos from page 1 for aksakalli.
# Fetching repositories for prof18...
# Fetched 71 repos from page 1 for prof18.
# Fetching repositories for MoeinDeveloper92...
# Fetched 72 repos from page 1 for MoeinDeveloper92.
# Fetching repositories for schriftgestalt...
# Fetched 100 repos from page 1 for schriftgestalt.
# Fetched 95 repos from page 2 for schriftgestalt.
# Fetching repositories for ManiMozaffar...
# Fetched 57 repos from page 1 for ManiMozaffar.
# Fetching repositories for cjolowicz...
# Fetched 100 repos from page 1 for cjolowicz.
# Fetched 100 repos from page 2 for cjolowicz.
# Fetched 4 repos from page 3 for cjolowicz.
# Fetching repositories for StephanEwen...
# Fetched 12 repos from page 1 for StephanEwen.
# Fetching repositories for boennemann...
# Fetched 62 repos from page 1 for boennemann.
# Fetching repositories for TheLartians...
# Fetched 55 repos from page 1 for TheLartians.
# Fetching repositories for ravanscafi...
# Fetched 16 repos from page 1 for ravanscafi.
# Fetching repositories for turbo...
# Fetched 100 repos from page 1 for turbo.
# Fetched 100 repos from page 2 for turbo.
# Fetched 12 repos from page 3 for turbo.
# Fetching repositories for gumb0...
# Fetched 46 repos from page 1 for gumb0.
# Fetching repositories for guitmz...
# Fetched 100 repos from page 1 for guitmz.
# Fetched 32 repos from page 2 for guitmz.
# Fetching repositories for squat...
# Fetched 100 repos from page 1 for squat.
# Fetched 41 repos from page 2 for squat.
# Fetching repositories for zubairehman...
# Fetched 100 repos from page 1 for zubairehman.
# Fetched 21 repos from page 2 for zubairehman.
# Fetching repositories for burnash...
# Fetched 40 repos from page 1 for burnash.
# Fetching repositories for lisacharlotterost...
# Fetched 11 repos from page 1 for lisacharlotterost.
# Fetching repositories for TimDaub...
# Fetched 100 repos from page 1 for TimDaub.
# Fetched 89 repos from page 2 for TimDaub.
# Fetching repositories for axsaucedo...
# Fetched 100 repos from page 1 for axsaucedo.
# Fetched 88 repos from page 2 for axsaucedo.
# Fetching repositories for Skn0tt...
# Fetched 100 repos from page 1 for Skn0tt.
# Fetched 93 repos from page 2 for Skn0tt.
# Fetching repositories for kkaefer...
# Fetched 94 repos from page 1 for kkaefer.
# Fetching repositories for lgrammel...
# Fetched 83 repos from page 1 for lgrammel.
# Fetching repositories for Fcmam5...
# Fetched 100 repos from page 1 for Fcmam5.
# Fetched 47 repos from page 2 for Fcmam5.
# Fetching repositories for aap...
# Fetched 54 repos from page 1 for aap.
# Fetching repositories for brauner...
# Fetched 80 repos from page 1 for brauner.
# Fetching repositories for juliuste...
# Fetched 100 repos from page 1 for juliuste.
# Fetched 41 repos from page 2 for juliuste.
# Fetching repositories for fehmicansaglam...
# Fetched 64 repos from page 1 for fehmicansaglam.
# Fetching repositories for mrtazz...
# Fetched 100 repos from page 1 for mrtazz.
# Fetched 5 repos from page 2 for mrtazz.
# Fetching repositories for weaveworks...
# Fetched 100 repos from page 1 for weaveworks.
# Fetched 46 repos from page 2 for weaveworks.
# Fetching repositories for acao...
# Fetched 100 repos from page 1 for acao.
# Fetched 57 repos from page 2 for acao.
# Fetching repositories for whoenig...
# Fetched 42 repos from page 1 for whoenig.
# Fetching repositories for cloudpanel-io...
# Fetched 14 repos from page 1 for cloudpanel-io.
# Fetching repositories for runningcode...
# Fetched 100 repos from page 1 for runningcode.
# Fetched 66 repos from page 2 for runningcode.
# Fetching repositories for laramartin...
# Fetched 78 repos from page 1 for laramartin.
# Fetching repositories for baptistebriel...
# Fetched 13 repos from page 1 for baptistebriel.
# Fetching repositories for ashiishme...
# Fetched 96 repos from page 1 for ashiishme.
# Fetching repositories for jhass...
# Fetched 79 repos from page 1 for jhass.
# Fetching repositories for imskr...
# Fetched 100 repos from page 1 for imskr.
# Fetched 8 repos from page 2 for imskr.
# Fetching repositories for MarkusH...
# Fetched 100 repos from page 1 for MarkusH.
# Fetched 17 repos from page 2 for MarkusH.
# Fetching repositories for soundcloud...
# Fetched 57 repos from page 1 for soundcloud.
# Fetching repositories for andela-sjames...
# Fetched 76 repos from page 1 for andela-sjames.
# Fetching repositories for fortmarek...
# Fetched 88 repos from page 1 for fortmarek.
# Fetching repositories for RomelTorres...
# Fetched 29 repos from page 1 for RomelTorres.
# Fetching repositories for chrisguttandin...
# Fetched 100 repos from page 1 for chrisguttandin.
# Fetched 32 repos from page 2 for chrisguttandin.
# Fetching repositories for jamiehannaford...
# Fetched 99 repos from page 1 for jamiehannaford.
# Fetching repositories for Pisush...
# Fetched 41 repos from page 1 for Pisush.
# Fetching repositories for ym...
# Fetched 100 repos from page 1 for ym.
# Fetched 61 repos from page 2 for ym.
# Fetching repositories for MichaelKreil...
# Fetched 100 repos from page 1 for MichaelKreil.
# Fetched 21 repos from page 2 for MichaelKreil.
# Fetching repositories for laf0rge...
# Fetched 36 repos from page 1 for laf0rge.
# Fetching repositories for perusio...
# Fetched 100 repos from page 1 for perusio.
# Fetched 35 repos from page 2 for perusio.
# Fetching repositories for martinklepsch...
# Fetched 100 repos from page 1 for martinklepsch.
# Fetched 100 repos from page 2 for martinklepsch.
# Fetched 51 repos from page 3 for martinklepsch.
# Fetching repositories for alexbeletsky...
# Fetched 100 repos from page 1 for alexbeletsky.
# Fetched 33 repos from page 2 for alexbeletsky.
# Fetching repositories for marcinguy...
# Fetched 19 repos from page 1 for marcinguy.
# Fetching repositories for janeczku...
# Fetched 100 repos from page 1 for janeczku.
# Fetched 85 repos from page 2 for janeczku.
# Fetching repositories for manojpandey...
# Fetched 100 repos from page 1 for manojpandey.
# Fetched 34 repos from page 2 for manojpandey.
# Fetching repositories for fineanmol...
# Fetched 100 repos from page 1 for fineanmol.
# Fetched 22 repos from page 2 for fineanmol.
# Fetching repositories for gorgos...
# Fetched 42 repos from page 1 for gorgos.
# Fetching repositories for traumverloren...
# Fetched 100 repos from page 1 for traumverloren.
# Fetched 49 repos from page 2 for traumverloren.
# Fetching repositories for jackschaedler...
# Fetched 12 repos from page 1 for jackschaedler.
# Fetching repositories for syllog1sm...
# Fetched 19 repos from page 1 for syllog1sm.
# Fetching repositories for dirkschumacher...
# Fetched 100 repos from page 1 for dirkschumacher.
# Fetched 57 repos from page 2 for dirkschumacher.
# Fetching repositories for ngoduykhanh...
# Fetched 33 repos from page 1 for ngoduykhanh.
# Fetching repositories for doctolib...
# Fetched 55 repos from page 1 for doctolib.
# Fetching repositories for fractaledmind...
# Fetched 100 repos from page 1 for fractaledmind.
# Fetched 5 repos from page 2 for fractaledmind.
# Fetching repositories for smurawski...
# Fetched 83 repos from page 1 for smurawski.
# Fetching repositories for woachk...
# Fetched 52 repos from page 1 for woachk.
# Fetching repositories for sdepold...
# Fetched 100 repos from page 1 for sdepold.
# Fetched 100 repos from page 2 for sdepold.
# Fetched 4 repos from page 3 for sdepold.
# Fetching repositories for Kardelio...
# Fetched 84 repos from page 1 for Kardelio.
# Fetching repositories for pauladiniz...
# Fetched 61 repos from page 1 for pauladiniz.
# Fetching repositories for coderobe...
# Fetched 100 repos from page 1 for coderobe.
# Fetched 46 repos from page 2 for coderobe.
# Fetching repositories for marimeireles...
# Fetched 100 repos from page 1 for marimeireles.
# Fetched 86 repos from page 2 for marimeireles.
# Fetching repositories for CesarValiente...
# Fetched 62 repos from page 1 for CesarValiente.
# Fetching repositories for abdulfatir...
# Fetched 58 repos from page 1 for abdulfatir.
# Fetching repositories for carolstran...
# Fetched 26 repos from page 1 for carolstran.
# Fetching repositories for spicedacademy...
# Fetched 7 repos from page 1 for spicedacademy.
# Fetching repositories for htbkoo...
# Fetched 100 repos from page 1 for htbkoo.
# Fetched 100 repos from page 2 for htbkoo.
# Fetched 82 repos from page 3 for htbkoo.
# Fetching repositories for bluemix...
# Fetched 100 repos from page 1 for bluemix.
# Fetched 5 repos from page 2 for bluemix.
# Fetching repositories for jdennes...
# Fetched 57 repos from page 1 for jdennes.
# Fetching repositories for janlelis...
# Fetched 100 repos from page 1 for janlelis.
# Fetched 27 repos from page 2 for janlelis.
# Fetching repositories for andydandy74...
# Fetched 6 repos from page 1 for andydandy74.
# Fetching repositories for zoepage...
# Fetched 33 repos from page 1 for zoepage.
# Fetching repositories for aqrln...
# Fetched 75 repos from page 1 for aqrln.
# Fetching repositories for gkmngrgn...
# Fetched 14 repos from page 1 for gkmngrgn.
# Fetching repositories for brunagil...
# Fetched 60 repos from page 1 for brunagil.
# Fetching repositories for mwarning...
# Fetched 57 repos from page 1 for mwarning.
# Fetching repositories for JustinShenk...
# Fetched 82 repos from page 1 for JustinShenk.
# Fetching repositories for tssovi...
# Fetched 46 repos from page 1 for tssovi.
# Fetching repositories for mmourafiq...
# Fetched 96 repos from page 1 for mmourafiq.
# Fetching repositories for deanm...
# Fetched 42 repos from page 1 for deanm.
# Fetching repositories for thejonanshow...
# Fetched 100 repos from page 1 for thejonanshow.
# Fetched 97 repos from page 2 for thejonanshow.
# Fetching repositories for discordianfish...
# Fetched 100 repos from page 1 for discordianfish.
# Fetched 100 repos from page 2 for discordianfish.
# Fetched 68 repos from page 3 for discordianfish.
# Fetching repositories for nikku...
# Fetched 100 repos from page 1 for nikku.
# Fetched 38 repos from page 2 for nikku.
# Fetching repositories for seiflotfy...
# Fetched 68 repos from page 1 for seiflotfy.
# Fetching repositories for cmaureir...
# Fetched 100 repos from page 1 for cmaureir.
# Fetched 39 repos from page 2 for cmaureir.
# Fetching repositories for yjs...
# Fetched 28 repos from page 1 for yjs.
# Fetching repositories for mindreframer...
# Fetched 100 repos from page 1 for mindreframer.
# Fetched 100 repos from page 2 for mindreframer.
# Fetched 100 repos from page 3 for mindreframer.
# Fetched 3 repos from page 4 for mindreframer.
# Fetching repositories for larsxschneider...
# Fetched 87 repos from page 1 for larsxschneider.
# Fetching repositories for yomete...
# Fetched 90 repos from page 1 for yomete.
# Fetching repositories for johnjohndoe...
# Fetched 100 repos from page 1 for johnjohndoe.
# Fetched 100 repos from page 2 for johnjohndoe.
# Fetched 100 repos from page 3 for johnjohndoe.
# Fetched 82 repos from page 4 for johnjohndoe.
# Fetching repositories for missinglink...
# Fetched 100 repos from page 1 for missinglink.
# Fetched 100 repos from page 2 for missinglink.
# Fetched 53 repos from page 3 for missinglink.
# Fetching repositories for Victoriapm...
# Fetched 43 repos from page 1 for Victoriapm.
# Fetching repositories for lourot...
# Fetched 56 repos from page 1 for lourot.
# Fetching repositories for felipecruz...
# Fetched 34 repos from page 1 for felipecruz.
# Fetching repositories for zalandoresearch...
# Fetched 26 repos from page 1 for zalandoresearch.
# Fetching repositories for yogiben...
# Fetched 95 repos from page 1 for yogiben.
# Fetching repositories for janober...
# Fetched 26 repos from page 1 for janober.
# Fetching repositories for fhueske...
# Fetched 23 repos from page 1 for fhueske.
# Fetching repositories for nickstenning...
# Fetched 100 repos from page 1 for nickstenning.
# Fetched 79 repos from page 2 for nickstenning.
# Fetching repositories for adriankumpf...
# Fetched 53 repos from page 1 for adriankumpf.
# Fetching repositories for laurmaedje...
# Fetched 30 repos from page 1 for laurmaedje.
# Fetching repositories for anna-geller...
# Fetched 50 repos from page 1 for anna-geller.
# Fetching repositories for vasco-santos...
# Fetched 90 repos from page 1 for vasco-santos.
# Fetching repositories for neobrain...
# Fetched 40 repos from page 1 for neobrain.
# Fetching repositories for jfahrenkrug...
# Fetched 97 repos from page 1 for jfahrenkrug.
# Fetching repositories for kshitij10496...
# Fetched 32 repos from page 1 for kshitij10496.
# Fetching repositories for d3vilbug...
# Fetched 4 repos from page 1 for d3vilbug.
# Fetching repositories for grobie...
# Fetched 65 repos from page 1 for grobie.
# Fetching repositories for AlaaAttya...
# Fetched 100 repos from page 1 for AlaaAttya.
# Fetched 13 repos from page 2 for AlaaAttya.
# Fetching repositories for atilafassina...
# Fetched 89 repos from page 1 for atilafassina.
# Fetching repositories for streadway...
# Fetched 39 repos from page 1 for streadway.
# Fetching repositories for rafaeljesus...
# Fetched 100 repos from page 1 for rafaeljesus.
# Fetched 100 repos from page 2 for rafaeljesus.
# Fetched 12 repos from page 3 for rafaeljesus.
# Fetching repositories for goetas...
# Fetched 93 repos from page 1 for goetas.
# Fetching repositories for davidfurlong...
# Fetched 100 repos from page 1 for davidfurlong.
# Fetched 71 repos from page 2 for davidfurlong.
# Fetching repositories for objcio...
# Fetched 100 repos from page 1 for objcio.
# Fetched 100 repos from page 2 for objcio.
# Fetched 100 repos from page 3 for objcio.
# Fetched 100 repos from page 4 for objcio.
# Fetched 77 repos from page 5 for objcio.
# Fetching repositories for vitling...
# Fetched 21 repos from page 1 for vitling.
# Fetching repositories for objectbox...
# Fetched 34 repos from page 1 for objectbox.
# Fetching repositories for anaschwendler...
# Fetched 42 repos from page 1 for anaschwendler.
# Fetching repositories for daniel-j-h...
# Fetched 100 repos from page 1 for daniel-j-h.
# Fetched 40 repos from page 2 for daniel-j-h.
# Fetching repositories for Nitrokey...
# Fetched 100 repos from page 1 for Nitrokey.
# Fetched 99 repos from page 2 for Nitrokey.
# Fetching repositories for sejalv...
# Fetched 21 repos from page 1 for sejalv.
# Fetching repositories for hamoid...
# Fetched 34 repos from page 1 for hamoid.
# Fetching repositories for chrxh...
# Fetched 7 repos from page 1 for chrxh.
# Fetching repositories for mr-c...
# Fetched 100 repos from page 1 for mr-c.
# Fetched 100 repos from page 2 for mr-c.
# Fetched 100 repos from page 3 for mr-c.
# Fetched 100 repos from page 4 for mr-c.
# Fetched 74 repos from page 5 for mr-c.
# Fetching repositories for yogmel...
# Fetched 52 repos from page 1 for yogmel.
# Fetching repositories for Drakulix...
# Fetched 59 repos from page 1 for Drakulix.
# Fetching repositories for DenisovAV...
# Fetched 44 repos from page 1 for DenisovAV.
# Fetching repositories for adrianheine...
# Fetched 86 repos from page 1 for adrianheine.
# Fetching repositories for al2na...
# Fetched 73 repos from page 1 for al2na.
# Fetching repositories for thyrlian...
# Fetched 81 repos from page 1 for thyrlian.
# Fetching repositories for septag...
# Fetched 41 repos from page 1 for septag.
# Fetching repositories for mishushakov...
# Fetched 44 repos from page 1 for mishushakov.
# Fetching repositories for asaaki...
# Fetched 100 repos from page 1 for asaaki.
# Fetched 46 repos from page 2 for asaaki.
# Fetching repositories for lorey...
# Fetched 34 repos from page 1 for lorey.
# Fetching repositories for talitaoliveira...
# Fetched 93 repos from page 1 for talitaoliveira.
# Fetching repositories for unnamedd...
# Fetched 100 repos from page 1 for unnamedd.
# Fetched 49 repos from page 2 for unnamedd.
# Fetching repositories for Fouloscopie...
# Fetched 1 repos from page 1 for Fouloscopie.
# Fetching repositories for arianvp...
# Fetched 100 repos from page 1 for arianvp.
# Fetched 100 repos from page 2 for arianvp.
# Fetched 90 repos from page 3 for arianvp.
# Fetching repositories for marktani...
# Fetched 100 repos from page 1 for marktani.
# Fetched 7 repos from page 2 for marktani.
# Fetching repositories for nomicode...
# Fetched 27 repos from page 1 for nomicode.
# Fetching repositories for alanakbik...
# Fetched 9 repos from page 1 for alanakbik.
# Fetching repositories for Licenser...
# Fetched 100 repos from page 1 for Licenser.
# Fetched 100 repos from page 2 for Licenser.
# Fetched 24 repos from page 3 for Licenser.
# Fetching repositories for sacridini...
# Fetched 52 repos from page 1 for sacridini.
# Fetching repositories for Khaledgarbaya...
# Fetched 100 repos from page 1 for Khaledgarbaya.
# Fetched 96 repos from page 2 for Khaledgarbaya.
# Fetching repositories for s1monw...
# Fetched 18 repos from page 1 for s1monw.
# Fetching repositories for angelikatyborska...
# Fetched 63 repos from page 1 for angelikatyborska.
# Fetching repositories for IliaKani...
# Fetched 15 repos from page 1 for IliaKani.
# Fetching repositories for bennycode...
# Fetched 100 repos from page 1 for bennycode.
# Fetched 100 repos from page 2 for bennycode.
# Fetched 98 repos from page 3 for bennycode.
# Fetching repositories for Kovah...
# Fetched 43 repos from page 1 for Kovah.
# Fetching repositories for tsterbak...
# Fetched 48 repos from page 1 for tsterbak.
# Fetching repositories for sorenbs...
# Fetched 41 repos from page 1 for sorenbs.
# Fetching repositories for mrflix...
# Fetched 48 repos from page 1 for mrflix.
# Fetching repositories for rixx...
# Fetched 100 repos from page 1 for rixx.
# Fetched 69 repos from page 2 for rixx.
# Fetching repositories for reuben...
# Fetched 100 repos from page 1 for reuben.
# Fetched 28 repos from page 2 for reuben.
# Fetching repositories for RosaWagner...
# Fetched 2 repos from page 1 for RosaWagner.
# Fetching repositories for dpreussler...
# Fetched 41 repos from page 1 for dpreussler.
# Fetching repositories for rivo...
# Fetched 13 repos from page 1 for rivo.
# Fetching repositories for lucaong...
# Fetched 64 repos from page 1 for lucaong.
# Fetching repositories for fabsx00...
# Fetched 21 repos from page 1 for fabsx00.
# Fetching repositories for janmonschke...
# Fetched 100 repos from page 1 for janmonschke.
# Fetching repositories for sotte...
# Fetched 100 repos from page 1 for sotte.
# Fetched 5 repos from page 2 for sotte.
# Fetching repositories for spacecowb0y...
# Fetched 96 repos from page 1 for spacecowb0y.
# Fetching repositories for candostdagdeviren...
# Fetched 28 repos from page 1 for candostdagdeviren.
# Fetching repositories for kenshinji...
# Fetched 100 repos from page 1 for kenshinji.
# Fetched 41 repos from page 2 for kenshinji.
# Fetching repositories for lstoll...
# Fetched 100 repos from page 1 for lstoll.
# Fetched 100 repos from page 2 for lstoll.
# Fetched 28 repos from page 3 for lstoll.
# Fetching repositories for denisdefreyne...
# Fetched 100 repos from page 1 for denisdefreyne.
# Fetched 28 repos from page 2 for denisdefreyne.
# Fetching repositories for Sly777...
# Fetched 77 repos from page 1 for Sly777.
# Fetching repositories for MKRLancer...
# Fetched 15 repos from page 1 for MKRLancer.
# Fetching repositories for jmattheis...
# Fetched 21 repos from page 1 for jmattheis.
# Fetching repositories for OskarStark...
# Fetched 100 repos from page 1 for OskarStark.
# Fetched 100 repos from page 2 for OskarStark.
# Fetched 100 repos from page 3 for OskarStark.
# Fetched 3 repos from page 4 for OskarStark.
# Fetching repositories for cmichi...
# Fetched 56 repos from page 1 for cmichi.
# Fetching repositories for esoxjem...
# Fetched 25 repos from page 1 for esoxjem.
# Fetching repositories for saschanaz...
# Fetched 100 repos from page 1 for saschanaz.
# Fetched 100 repos from page 2 for saschanaz.
# Fetched 100 repos from page 3 for saschanaz.
# Fetched 92 repos from page 4 for saschanaz.
# Fetching repositories for montogeek...
# Fetched 100 repos from page 1 for montogeek.
# Fetched 100 repos from page 2 for montogeek.
# Fetched 74 repos from page 3 for montogeek.
# Fetching repositories for Letty...
# Fetched 20 repos from page 1 for Letty.
# Fetching repositories for clovisdasilvaneto...
# Fetched 100 repos from page 1 for clovisdasilvaneto.
# Fetched 57 repos from page 2 for clovisdasilvaneto.
# Fetching repositories for autophagy...
# Fetched 72 repos from page 1 for autophagy.
# Fetching repositories for marcobiedermann...
# Fetched 58 repos from page 1 for marcobiedermann.
# Fetching repositories for efemoney...
# Fetched 23 repos from page 1 for efemoney.
# Fetching repositories for niderhoff...
# Fetched 24 repos from page 1 for niderhoff.
# Fetching repositories for omergulen...
# Fetched 97 repos from page 1 for omergulen.
# Fetching repositories for kimar...
# Fetched 100 repos from page 1 for kimar.
# Fetched 53 repos from page 2 for kimar.
# Fetching repositories for progapandist...
# Fetched 46 repos from page 1 for progapandist.
# Fetching repositories for marinho...
# Fetched 100 repos from page 1 for marinho.
# Fetched 29 repos from page 2 for marinho.
# Fetching repositories for aarlt...
# Fetched 43 repos from page 1 for aarlt.
# Fetching repositories for devonestes...
# Fetched 74 repos from page 1 for devonestes.
# Fetching repositories for manuelbieh...
# Fetched 83 repos from page 1 for manuelbieh.
# Fetching repositories for irh...
# Fetched 46 repos from page 1 for irh.
# Fetching repositories for lukasoppermann...
# Fetched 78 repos from page 1 for lukasoppermann.
# Fetching repositories for joseliacosta...
# Fetched 70 repos from page 1 for joseliacosta.
# Fetching repositories for hartwork...
# Fetched 100 repos from page 1 for hartwork.
# Fetched 90 repos from page 2 for hartwork.
# Fetching repositories for s-soroosh...
# Fetched 100 repos from page 1 for s-soroosh.
# Fetched 23 repos from page 2 for s-soroosh.
# Fetching repositories for polarity...
# Fetched 49 repos from page 1 for polarity.
# Fetching repositories for Rebaiahmed...
# Fetched 100 repos from page 1 for Rebaiahmed.
# Fetched 77 repos from page 2 for Rebaiahmed.
# Fetching repositories for fmeyer...
# Fetched 69 repos from page 1 for fmeyer.
# Fetching repositories for hanakamer...
# Fetched 56 repos from page 1 for hanakamer.
# Fetching repositories for mlegy...
# Fetched 55 repos from page 1 for mlegy.
# Fetching repositories for Kriesse...
# Fetched 45 repos from page 1 for Kriesse.
# Fetching repositories for szaimen...
# Fetched 13 repos from page 1 for szaimen.
# Fetching repositories for geekdada...
# Fetched 78 repos from page 1 for geekdada.
# Fetching repositories for Dylan-DPC-zz...
# Fetched 100 repos from page 1 for Dylan-DPC-zz.
# Fetched 79 repos from page 2 for Dylan-DPC-zz.
# Fetching repositories for linki...
# Fetched 100 repos from page 1 for linki.
# Fetched 20 repos from page 2 for linki.
# Fetching repositories for keremciu...
# Fetched 82 repos from page 1 for keremciu.
# Fetching repositories for aep...
# Fetched 100 repos from page 1 for aep.
# Fetched 100 repos from page 2 for aep.
# Fetched 19 repos from page 3 for aep.
# Fetching repositories for stanislaw...
# Fetched 70 repos from page 1 for stanislaw.
# Fetching repositories for msoos...
# Fetched 70 repos from page 1 for msoos.
# Fetching repositories for chrippa...
# Fetched 26 repos from page 1 for chrippa.
# Fetching repositories for Goldziher...
# Fetched 21 repos from page 1 for Goldziher.
# Fetching repositories for danielpaulus...
# Fetched 38 repos from page 1 for danielpaulus.
# Fetching repositories for bashofmann...
# Fetched 100 repos from page 1 for bashofmann.
# Fetched 66 repos from page 2 for bashofmann.
# Fetching repositories for BenchR267...
# Fetched 22 repos from page 1 for BenchR267.
# Fetching repositories for phazonoverload...
# Fetched 74 repos from page 1 for phazonoverload.
# Fetching repositories for Mark2Mark...
# Fetched 52 repos from page 1 for Mark2Mark.
# Fetching repositories for jenskutilek...
# Fetched 68 repos from page 1 for jenskutilek.
# Fetching repositories for moiseshorta...
# Fetched 34 repos from page 1 for moiseshorta.
# Fetching repositories for v-thakkar...
# Fetched 60 repos from page 1 for v-thakkar.
# Fetching repositories for LukasReschke...
# Fetched 74 repos from page 1 for LukasReschke.
# Fetching repositories for joaomilho...
# Fetched 43 repos from page 1 for joaomilho.
# Fetching repositories for 343max...
# Fetched 100 repos from page 1 for 343max.
# Fetched 70 repos from page 2 for 343max.
# Fetching repositories for kirel...
# Fetched 63 repos from page 1 for kirel.
# Fetching repositories for akrennmair...
# Fetched 80 repos from page 1 for akrennmair.
# Fetching repositories for oleiade...
# Fetched 77 repos from page 1 for oleiade.
# Fetching repositories for PavelLaptev...
# Fetched 84 repos from page 1 for PavelLaptev.
# Fetching repositories for mschneider...
# Fetched 99 repos from page 1 for mschneider.
# Fetching repositories for froschi...
# Fetched 100 repos from page 1 for froschi.
# Fetched 69 repos from page 2 for froschi.
# Fetching repositories for tmylk...
# Fetched 43 repos from page 1 for tmylk.
# Fetching repositories for robinpokorny...
# Fetched 100 repos from page 1 for robinpokorny.
# Fetched 69 repos from page 2 for robinpokorny.
# Fetching repositories for EmaSuriano...
# Fetched 100 repos from page 1 for EmaSuriano.
# Fetched 55 repos from page 2 for EmaSuriano.
# Fetching repositories for philippkuehn...
# Fetched 11 repos from page 1 for philippkuehn.
# Fetching repositories for LeonardoCardoso...
# Fetched 53 repos from page 1 for LeonardoCardoso.
# Fetching repositories for JeroenDeDauw...
# Fetched 100 repos from page 1 for JeroenDeDauw.
# Fetched 100 repos from page 2 for JeroenDeDauw.
# Fetched 94 repos from page 3 for JeroenDeDauw.
# Fetching repositories for Musti4096...
# Fetched 22 repos from page 1 for Musti4096.
# Fetching repositories for finnp...
# Fetched 100 repos from page 1 for finnp.
# Fetched 100 repos from page 2 for finnp.
# Fetched 100 repos from page 3 for finnp.
# Fetched 53 repos from page 4 for finnp.
# Fetching repositories for mirshko...
# Fetched 94 repos from page 1 for mirshko.
# Fetching repositories for zeenix...
# Fetched 94 repos from page 1 for zeenix.
# Fetching repositories for vecna...
# Fetched 49 repos from page 1 for vecna.
# Fetching repositories for alfredfrancis...
# Fetched 91 repos from page 1 for alfredfrancis.
# Fetching repositories for MichaelKohler...
# Fetched 100 repos from page 1 for MichaelKohler.
# Fetched 100 repos from page 2 for MichaelKohler.
# Fetched 53 repos from page 3 for MichaelKohler.
# Fetching repositories for helmuthdu...
# Fetched 29 repos from page 1 for helmuthdu.
# Fetching repositories for polykit...
# Fetched 38 repos from page 1 for polykit.
# Fetching repositories for illume...
# Fetched 80 repos from page 1 for illume.
# Fetching repositories for 0mp...
# Fetched 100 repos from page 1 for 0mp.
# Fetched 100 repos from page 2 for 0mp.
# Fetched 100 repos from page 3 for 0mp.
# Fetched 8 repos from page 4 for 0mp.
# Fetching repositories for harshil1712...
# Fetched 100 repos from page 1 for harshil1712.
# Fetched 72 repos from page 2 for harshil1712.
# Fetching repositories for kurasu...
# Fetched 5 repos from page 1 for kurasu.
# Fetching repositories for robinboehm...
# Fetched 100 repos from page 1 for robinboehm.
# Fetched 69 repos from page 2 for robinboehm.
# Fetching repositories for tunavargi...
# Fetched 27 repos from page 1 for tunavargi.
# Fetching repositories for miconda...
# Fetched 43 repos from page 1 for miconda.
# Fetching repositories for mohsenoid...
# Fetched 100 repos from page 1 for mohsenoid.
# Fetched 5 repos from page 2 for mohsenoid.
# Fetching repositories for katiayn...
# Fetched 55 repos from page 1 for katiayn.
# Fetching repositories for rockstaedt...
# Fetched 12 repos from page 1 for rockstaedt.
# Fetching repositories for tmspzz...
# Fetched 55 repos from page 1 for tmspzz.
# Fetching repositories for tanvir002700...
# Fetched 53 repos from page 1 for tanvir002700.
# Fetching repositories for cristianoliveira...
# Fetched 94 repos from page 1 for cristianoliveira.
# Fetching repositories for HeyPouya...
# Fetched 66 repos from page 1 for HeyPouya.
# Fetching repositories for mrchrisadams...
# Fetched 100 repos from page 1 for mrchrisadams.
# Fetched 100 repos from page 2 for mrchrisadams.
# Fetched 39 repos from page 3 for mrchrisadams.
# Fetching repositories for mymindishazel...
# Fetched 20 repos from page 1 for mymindishazel.
# Fetching repositories for codeliner...
# Fetched 73 repos from page 1 for codeliner.
# Fetching repositories for rishimohan...
# Fetched 35 repos from page 1 for rishimohan.
# Fetching repositories for myobie...
# Fetched 100 repos from page 1 for myobie.
# Fetched 68 repos from page 2 for myobie.
# Fetching repositories for chris-rock...
# Fetched 100 repos from page 1 for chris-rock.
# Fetched 79 repos from page 2 for chris-rock.
# Fetching repositories for fabianfett...
# Fetched 37 repos from page 1 for fabianfett.
# Fetching repositories for MedRedha...
# Fetched 100 repos from page 1 for MedRedha.
# Fetched 100 repos from page 2 for MedRedha.
# Fetched 100 repos from page 3 for MedRedha.
# Fetched 6 repos from page 4 for MedRedha.
# Fetching repositories for durannumit...
# Fetched 42 repos from page 1 for durannumit.
# Fetching repositories for khanzadimahdi...
# Fetched 21 repos from page 1 for khanzadimahdi.
# Fetching repositories for divyenduz...
# Fetched 28 repos from page 1 for divyenduz.
# Fetching repositories for sunsided...
# Fetched 100 repos from page 1 for sunsided.
# Fetched 100 repos from page 2 for sunsided.
# Fetched 100 repos from page 3 for sunsided.
# Fetched 53 repos from page 4 for sunsided.
# Fetching repositories for cornelius...
# Fetched 100 repos from page 1 for cornelius.
# Fetched 6 repos from page 2 for cornelius.
# Fetching repositories for anna-carroll...
# Fetched 11 repos from page 1 for anna-carroll.
# Fetching repositories for pierluigiferrari...
# Fetched 20 repos from page 1 for pierluigiferrari.
# Fetching repositories for Fluepke...
# Fetched 55 repos from page 1 for Fluepke.
# Fetching repositories for adewes...
# Fetched 51 repos from page 1 for adewes.
# Fetching repositories for Schaeff...
# Fetched 53 repos from page 1 for Schaeff.
# Fetching repositories for luqmanoop...
# Fetched 100 repos from page 1 for luqmanoop.
# Fetched 20 repos from page 2 for luqmanoop.
# Fetching repositories for amn41...
# Fetched 30 repos from page 1 for amn41.
# Fetching repositories for natalyapeixoto...
# Fetched 77 repos from page 1 for natalyapeixoto.
# Fetching repositories for znarf...
# Fetched 48 repos from page 1 for znarf.
# Fetching repositories for adzialocha...
# Fetched 64 repos from page 1 for adzialocha.
# Fetching repositories for mikiobraun...
# Fetched 30 repos from page 1 for mikiobraun.
# Fetching repositories for BenjaminBossan...
# Fetched 46 repos from page 1 for BenjaminBossan.
# Fetching repositories for vadorovsky...
# Fetched 100 repos from page 1 for vadorovsky.
# Fetched 100 repos from page 2 for vadorovsky.
# Fetched 100 repos from page 3 for vadorovsky.
# Fetched 11 repos from page 4 for vadorovsky.
# Fetching repositories for mzaks...
# Fetched 63 repos from page 1 for mzaks.
# Fetching repositories for chootka...
# Fetched 48 repos from page 1 for chootka.
# Fetching repositories for knutin...
# Fetched 74 repos from page 1 for knutin.
# Fetching repositories for batin...
# Fetched 44 repos from page 1 for batin.
# Fetching repositories for Shpota...
# Fetched 37 repos from page 1 for Shpota.
# Fetching repositories for reactormonk...
# Fetched 100 repos from page 1 for reactormonk.
# Fetched 100 repos from page 2 for reactormonk.
# Fetched 34 repos from page 3 for reactormonk.
# Fetching repositories for nulltea...
# Fetched 73 repos from page 1 for nulltea.
# Fetching repositories for holgerd77...
# Fetched 62 repos from page 1 for holgerd77.
# Fetching repositories for nmicht...
# Fetched 100 repos from page 1 for nmicht.
# Fetching repositories for Dineshkarthik...
# Fetched 42 repos from page 1 for Dineshkarthik.
# Fetching repositories for ogoffart...
# Fetched 15 repos from page 1 for ogoffart.
# Fetching repositories for zutrinken...
# Fetched 13 repos from page 1 for zutrinken.
# Fetching repositories for mustafaozhan...
# Fetched 30 repos from page 1 for mustafaozhan.
# Fetching repositories for carlosmn...
# Fetched 92 repos from page 1 for carlosmn.
# Fetching repositories for seia-soto...
# Fetched 100 repos from page 1 for seia-soto.
# Fetched 22 repos from page 2 for seia-soto.
# Fetching repositories for soulshake...
# Fetched 100 repos from page 1 for soulshake.
# Fetched 87 repos from page 2 for soulshake.
# Data saved to users.xlsx and repositories.xlsx

# %% [markdown]
# # **Question No - 13**

# %%
import pandas as pd
import statsmodels.api as sm

# Load the users data from the CSV file
users_df = pd.read_csv('users.csv', encoding='ISO-8859-1')

# Filter out users without bios
users_with_bios = users_df[users_df['bio'].notna()]

# Calculate the length of the bio in words
#users_with_bios['bio_word_count'] = users_with_bios['bio'].str.split(" ").str.len()

# The error was here: users_with_bio was used instead of users_with_bios
users_with_bios['bio_word_count'] = users_with_bios['bio'].apply(lambda x: len(x.split()))


# Prepare the data for regression
X = users_with_bios['bio_word_count']  # Independent variable
y = users_with_bios['followers']        # Dependent variable

# Add a constant to the independent variable for the regression
X = sm.add_constant(X)

# Fit the regression model
model = sm.OLS(y, X).fit()

# Get the regression slope (coefficient for bio_word_count)
slope = model.params['bio_word_count']

# Print the slope rounded to three decimal places
print(f'Regression slope of followers on bio word count: {slope:.4f}')
# Out:
# Regression slope of followers on bio word count: 28.7012
# <ipython-input-1-68bddb854169>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   users_with_bios['bio_word_count'] = users_with_bios['bio'].apply(lambda x: len(x.split()))
